# %% [markdown]
# # State of the current implementation
#
# This benchmark compares the performances of the latest version of [hdt_rs](https://github.com/konradhoeffner/hdt) with previous versions.
#
# It was executed on an Intel® Core™ i9-12900K CPU and 32 GiB of RAM.

# %%
# %matplotlib inline
from plot_utils import *

# %% [markdown]
# ## Evolution of hdt_rs
#
# The following graphs compare different versions of hdt_rs:
#
# * v0.1.8 compiled with rustc nightly v.1.79
# * v0.2.0 compiled with rustc nightly v1.79
#
# ### Evolution of the `query` test

# %%
VERSIONS = {
    #"hdt_rs-v0.1....": "#996666",
    #"hdt_rs-v0.1....: "#BB3333",
    #"hdt_rs-v0.1....": "#EE0000",
    "hdt_rs-v0.1.8": "#AAAAAA",
    "hdt_rs-v0.2.0": "#888888",
    "hdt_rs": "#00AA00",
}

plot_query_stats(load_data("query", *VERSIONS), color_key=VERSIONS, group=True)

# %% [markdown]
# ### Evolution of the `parse` test

# %%
plot_parse_stats(load_data("parse", *VERSIONS), color_key=VERSIONS, group=True)
